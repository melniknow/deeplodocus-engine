# %% [markdown]
# # deeplodocus-engine
#
# #### Шахматный движок, который проводит первичную фильтрацию ходов с помощью минимакса и выбирает лучший ход при помощи обученной MLP модели.
#
#
# <p style="text-align:center;"><img src="media/logo.png" alt="drawing" width="200"/></p>

# %% [markdown]
# ## Stockfish
# ### Чтобы иметь возможность посоревноваться с движком

# %%
from __future__ import division

import os
import time
import random

import socket
import json

import chess
import chess.pgn
import chess.uci
import stockfish

import numpy as np
import keras
from keras.models import load_model

# https://stockfishchess.org/download/
stockfishEngine = stockfish.Stockfish(path="/home/sergey/stockfish/stockfish-ubuntu-x86-64-avx2", depth=8)
# Out:
# /tmp/ipykernel_131737/2465506089.py:12: DeprecationWarning: The chess.uci module is deprecated in favor of
# chess.engine <https://python-chess.readthedocs.io/en/latest/engine.html>.
#
# Please consider updating and open an issue
# <https://github.com/niklasf/python-chess/issues/new> if your use case
# is not covered by the new API.
#   import chess.uci
# 2023-09-07 15:04:10.631205: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Deeplodocus model
# ### Импортируем обученную модель

# %%
model = load_model('1_400_000_ep400.h5')
keras.utils.plot_model(model, to_file="arch.png",show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Преобразование доски в bitmap
#
# <p style="text-align:center;"><img src="media/board.jpg" alt="drawing" width="500"/></p>

# %%
def splitter(inputStr, black):
    inputStr = format(inputStr, "064b")
    tmp = [inputStr[i:i+8] for i in range(0, len(inputStr), 8)]
    for i in range(0, len(tmp)):
        tmp2 = list(tmp[i])
        tmp2 = [int(x) * black for x in tmp2]
        tmp[i] = tmp2

    return tmp

def get_bitmap(board):
    bitmap = []
    
    P_input = splitter(int(board.pieces(chess.PAWN, chess.WHITE)), 1)
    R_input = splitter(int(board.pieces(chess.ROOK, chess.WHITE)), 1)
    N_input = splitter(int(board.pieces(chess.KNIGHT, chess.WHITE)), 1)
    B_input = splitter(int(board.pieces(chess.BISHOP, chess.WHITE)), 1)
    Q_input = splitter(int(board.pieces(chess.QUEEN, chess.WHITE)), 1)
    K_input = splitter(int(board.pieces(chess.KING, chess.WHITE)), 1)

    p_input = splitter(int(board.pieces(chess.PAWN, chess.BLACK)), -1)
    r_input = splitter(int(board.pieces(chess.ROOK, chess.BLACK)), -1)
    n_input = splitter(int(board.pieces(chess.KNIGHT, chess.BLACK)), -1)
    b_input = splitter(int(board.pieces(chess.BISHOP, chess.BLACK)), -1)
    q_input = splitter(int(board.pieces(chess.QUEEN, chess.BLACK)), -1)
    k_input = splitter(int(board.pieces(chess.KING, chess.BLACK)), -1)

    bitmap.extend(P_input)
    bitmap.extend(R_input)
    bitmap.extend(N_input)
    bitmap.extend(B_input)
    bitmap.extend(Q_input)
    bitmap.extend(K_input)
    bitmap.extend(p_input)
    bitmap.extend(r_input)
    bitmap.extend(n_input)
    bitmap.extend(b_input)
    bitmap.extend(q_input)
    bitmap.extend(k_input)

    return np.array([bitmap]).ravel()

# %% [markdown]
# ## Deeplodocus native
#
# ### Возможность поиграть с deeplodocus без минимакса

# %%
def simple_evaluate_best_move(board):
    max_ = -2
    res_move = 0
    
    if not board.turn:
        max_ = 2
    
    for move in board.legal_moves:
        board.push(move)
        bitmap = get_bitmap(board)
        pred = model.predict(np.array([bitmap]))[0][0]
        
        if not board.turn and pred > max_:
            max_ = pred
            res_move = move
        elif board.turn and pred < max_:
            max_ = pred
            res_move = move
        
        board.pop()
    
    return res_move.uci()

def get_best_move_by_deeplodocus_native(fen):
    board = chess.Board()
    board.set_fen(fen)
    
    return simple_evaluate_best_move(board)

# %% [markdown]
# ## Функция оценки для минимакса

# %%
def count_est_for_minimax(board, main_color, current_color):
    piece_value = {chess.PAWN:10, chess.KNIGHT:30,chess.BISHOP:30,chess.ROOK:50, chess.QUEEN:90}
    evaluation = 0
    for piece_type in [chess.PAWN, chess.KNIGHT, chess.BISHOP, chess.ROOK, chess.QUEEN]:
        evaluation += len(board.pieces(piece_type, main_color)) * piece_value.get(piece_type)
    
    is_mate = board.is_checkmate()
    
    if is_mate:
        if main_color == current_color:
            return 2000
        else:
            return -2000
    
    if board.is_stalemate():
        return -1 * evaluation
    
    return evaluation

def position_evaluation_for_minimax(board, main_color, current_color):
    return count_est_for_minimax(board, main_color,current_color) - \
            count_est_for_minimax(board, not main_color, current_color);

# %% [markdown]
# ## Алгоритм минимакса

# %%
def minimax(deep, max_deep, board, current_color, last_move, main_color, possible_moves, with_pruning, a, b):
    is_over = board.is_game_over()
    if deep == 0 or is_over:
        return [last_move, position_evaluation_for_minimax(board, main_color, not current_color)]
    
    is_max = current_color == main_color
    v = float("-inf") if is_max else float("inf")
    
    move_and_est = [[None], v]
    
    for move in possible_moves:
        board.push(move)
        recursive_value = minimax(deep - 1, max_deep, board, not current_color, move, \
                                    main_color, board.legal_moves, True, a, b)
        board.pop()
        
        if is_max:
            if with_pruning:
                a = max(a, recursive_value[1])
            if move_and_est[1] < recursive_value[1]:
                move_and_est = [[move], recursive_value[1]]
            elif deep == max_deep and move_and_est[1] == recursive_value[1]:
                move_and_est[0].append(move)
        else:
            if with_pruning:
                b = min(b, recursive_value[1])
            if move_and_est[1] > recursive_value[1]:
                move_and_est = [[move], recursive_value[1]]
            elif deep == max_deep and move_and_est[1] == recursive_value[1]:
                move_and_est[0].append(move)
        
        if with_pruning and b <= a:
            break
        
    return move_and_est

# %% [markdown]
# ## Выберем при помощи MLP лучший ход, среди предложенных минимаксом

# %%
def get_best_move_by_deeplodocus(fen):
    start_time = time.time()
    
    board = chess.Board()
    board.set_fen(fen)
    
    deep = 3
    minimax_reslt = minimax(deep, deep, board, board.turn, None, board.turn, \
                            board.legal_moves, False, float('-inf'), float('inf'))
    best_moves_ = minimax_reslt[0]
    
    print(minimax_reslt)
    
    max_ = -2
    res_move = 0
    
    if not board.turn:
        max_ = 2
    
    for move in best_moves_:
        board.push(move)
        bitmap = get_bitmap(board)
        pred = model.predict(np.array([bitmap]))[0][0]
        
        if not board.turn and pred > max_:
            max_ = pred
            res_move = move
        elif board.turn and pred < max_:
            max_ = pred
            res_move = move
        
        board.pop()
    
    print("--- %s seconds ---" % (time.time() - start_time))
    return res_move.uci()

# %% [markdown]
# ## Dto

# %%
class Dto:
    class ServerResponse:
        def __init__(self, move):
            self.move = move

    class ServerRequest:
        def __init__(self, fen, algorithm):
            self.fen = fen
            self.algorithm = algorithm

# %% [markdown]
# ## AiRunner
#
# Класс для запуска определённой модели по её имени

# %%
class AiRunner:
    @staticmethod
    def run(server_request):   
        if str(server_request.algorithm) == "STOCKFISH":   
            stockfishEngine.set_fen_position(server_request.fen)
            return Dto.ServerResponse(stockfishEngine.get_best_move())
        elif str(server_request.algorithm) == "DEEPLODOCUS_NATIVE":
            return Dto.ServerResponse(get_best_move_by_deeplodocus_native(server_request.fen))
        elif str(server_request.algorithm) == "DEEPLODOCUS":
            return Dto.ServerResponse(get_best_move_by_deeplodocus(server_request.fen))

# %% [markdown]
# ## Server
#
# Класс для запуска локального сервера

# %%
class Server:
    HOSTNAME = "localhost"
    PORT = 6671

    def __init__(self):
        self.server = socket.socket()
        self.server.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)

    def run(self):
        try:
            self.server.bind((self.HOSTNAME, self.PORT))
            self.server.listen()

            print("server starts")
            while True:
                con, addr = self.server.accept()
                json_str = con.recv(1024).decode('utf-8').replace('\n', '')

                print("server get data:", json_str)
                temp_obj = json.loads(json_str)

                server_req = Dto.ServerRequest(**temp_obj)
                server_res = AiRunner.run(server_req)

                message = json.dumps(server_res.__dict__)
                con.send(message.encode())

                print("server send message:", message)
                con.close()
        finally:
            self.server.close()

# %% [markdown]
# ## Запуск сервера

# %%
Server().run()
# Out:
# server starts
# server get data: {"fen":"rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('b1a3'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('a2a3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4'), Move.from_uci('a2a4')], 0]
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.4764258861541748 seconds ---
# server send message: {"move": "a2a3"}
# server get data: {"fen":"rnbqkbnr/pppppp1p/6p1/8/8/P7/1PPPPPPP/RNBQKBNR w KQkq - 0 2","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# --- 1.8663232326507568 seconds ---
# server send message: {"move": "e2e3"}
# server get data: {"fen":"rnbqkb1r/pppppp1p/5np1/8/8/P3P3/1PPP1PPP/RNBQKBNR w KQkq - 1 3","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('g1e2'), Move.from_uci('f1b5'), Move.from_uci('f1c4'), Move.from_uci('f1d3'), Move.from_uci('f1e2'), Move.from_uci('e1e2'), Move.from_uci('d1f3'), Move.from_uci('d1e2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# --- 2.6190788745880127 seconds ---
# server send message: {"move": "f1c4"}
# server get data: {"fen":"rnbqkb1r/pppp1p1p/4pnp1/8/2B5/P3P3/1PPP1PPP/RNBQK1NR w KQkq - 0 4","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4b5'), Move.from_uci('c4d3'), Move.from_uci('c4b3'), Move.from_uci('c4e2'), Move.from_uci('c4a2'), Move.from_uci('c4f1'), Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('g1e2'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('d1f3'), Move.from_uci('d1e2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('d2d4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 5.728550672531128 seconds ---
# server send message: {"move": "g1f3"}
# server get data: {"fen":"rnbq1b1r/ppppkp1p/4pnp1/8/2B5/P3PN2/1PPP1PPP/RNBQK2R w KQ - 2 5","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4b5'), Move.from_uci('c4d3'), Move.from_uci('c4b3'), Move.from_uci('c4e2'), Move.from_uci('c4a2'), Move.from_uci('c4f1'), Move.from_uci('f3g5'), Move.from_uci('f3e5'), Move.from_uci('f3h4'), Move.from_uci('f3d4'), Move.from_uci('f3g1'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('d1e2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('e1g1'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('d2d4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.208500146865845 seconds ---
# server send message: {"move": "f3g5"}
# server get data: {"fen":"rnbq1b1r/pp1pkp1p/2p1pnp1/6N1/2B5/P3P3/1PPP1PPP/RNBQK2R w KQ - 0 6","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3'), Move.from_uci('c4d3'), Move.from_uci('c4b3'), Move.from_uci('c4e2'), Move.from_uci('c4a2'), Move.from_uci('c4f1'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('d1f3'), Move.from_uci('d1e2'), Move.from_uci('a1a2'), Move.from_uci('e1g1'), Move.from_uci('e3e4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 5.525542974472046 seconds ---
# server send message: {"move": "c4b3"}
# server get data: {"fen":"rnbq1b1r/pp1pkp1p/4pnp1/2p3N1/8/PB2P3/1PPP1PPP/RNBQK2R w KQ - 0 7","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3'), Move.from_uci('b3c4'), Move.from_uci('b3a4'), Move.from_uci('b3a2'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('d1f3'), Move.from_uci('d1e2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('e1g1'), Move.from_uci('e3e4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('d2d4'), Move.from_uci('c2c4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 5.158018112182617 seconds ---
# server send message: {"move": "d2d4"}
# server get data: {"fen":"rnbq1b1r/pp1pkp1p/4pnp1/6N1/3p4/PB2P3/1PP2PPP/RNBQK2R w KQ - 0 8","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('d1d2'), Move.from_uci('c1d2'), Move.from_uci('e1g1'), Move.from_uci('c2c3')], -20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 5.34570837020874 seconds ---
# server send message: {"move": "c1d2"}
# server get data: {"fen":"rnbq1b1r/pp1pkp2/4pnpp/6N1/3p4/PB2P3/1PPB1PPP/RN1QK2R w KQ - 0 9","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3'), Move.from_uci('d2b4')], -20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 5.138079404830933 seconds ---
# server send message: {"move": "d2b4"}
# server get data: {"fen":"rnbqkb1r/pp1p1p2/4pnpp/6N1/1B1p4/PB2P3/1PP2PPP/RN1QK2R w KQ - 2 10","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3'), Move.from_uci('b4f8')], -20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.768080949783325 seconds ---
# server send message: {"move": "b4f8"}
# server get data: {"fen":"rnbq1k1r/pp1p1p2/4pnpp/6N1/3p4/PB2P3/1PP2PPP/RN1QK2R w KQ - 0 11","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g5h3'), Move.from_uci('g5f3')], -20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.63480281829834 seconds ---
# server send message: {"move": "g5f3"}
# server get data: {"fen":"rnb2k1r/pp1p1p2/4pnpp/q7/3p4/PB2PN2/1PP2PPP/RN1QK2R w KQ - 2 12","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d1d2')], -20]
# 1/1 [==============================] - 0s 13ms/step
# --- 2.992619037628174 seconds ---
# server send message: {"move": "d1d2"}
# server get data: {"fen":"rnb2k1r/pp1p1p2/4pnpp/8/3p4/PB2PN2/1PPq1PPP/RN2K2R w KQ - 0 13","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3d2'), Move.from_uci('b1d2')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.9065878391265869 seconds ---
# server send message: {"move": "b1d2"}
# server get data: {"fen":"rnb2k1r/pp1p1p2/5npp/4p3/3p4/PB2PN2/1PPN1PPP/R3K2R w KQ - 0 14","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3e5'), Move.from_uci('e3d4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.975364446640015 seconds ---
# server send message: {"move": "f3e5"}
# server get data: {"fen":"rnb2k1r/pp1p1p2/5npp/4N3/8/PB2p3/1PPN1PPP/R3K2R w KQ - 0 15","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f2e3')], 0]
# 1/1 [==============================] - 0s 13ms/step
# --- 6.7685770988464355 seconds ---
# server send message: {"move": "f2e3"}
# server get data: {"fen":"rnb2k1r/pp3p2/5npp/3pN3/8/PB2P3/1PPN2PP/R3K2R w KQ d6 0 16","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e5f3'), Move.from_uci('b3a4'), Move.from_uci('b3a2'), Move.from_uci('d2f3'), Move.from_uci('d2f1'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('e1f2'), Move.from_uci('e1e2'), Move.from_uci('e1f1'), Move.from_uci('e1d1'), Move.from_uci('a1a2'), Move.from_uci('a1d1'), Move.from_uci('a1c1'), Move.from_uci('e1g1'), Move.from_uci('e1c1'), Move.from_uci('a3a4'), Move.from_uci('g2g3'), Move.from_uci('c2c3'), Move.from_uci('h2h4'), Move.from_uci('c2c4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 6.266054391860962 seconds ---
# server send message: {"move": "e1c1"}
# server get data: {"fen":"rnb2k1r/pp1n1p2/6pp/3pN3/8/PB2P3/1PPN2PP/2KR3R w - - 2 17","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e5d7')], 10]
# 1/1 [==============================] - 0s 13ms/step
# --- 1.3763926029205322 seconds ---
# server send message: {"move": "e5d7"}
# server get data: {"fen":"rn3k1r/pp1b1p2/6pp/3p4/8/PB2P3/1PPN2PP/2KR3R w - - 0 18","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('b3d5')], 10]
# 1/1 [==============================] - 0s 13ms/step
# --- 1.7326881885528564 seconds ---
# server send message: {"move": "b3d5"}
# server get data: {"fen":"rn3k1r/pp3p2/2b3pp/3B4/8/P3P3/1PPN2PP/2KR3R w - - 1 19","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d5c6'), Move.from_uci('d5e4'), Move.from_uci('d5f3'), Move.from_uci('d2e4'), Move.from_uci('d2c4'), Move.from_uci('d2f3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('e3e4'), Move.from_uci('c2c4')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 2.0494513511657715 seconds ---
# server send message: {"move": "d5c6"}
# server get data: {"fen":"rn3k1r/p4p2/2p3pp/8/8/P3P3/1PPN2PP/2KR3R w - - 0 20","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d2e4'), Move.from_uci('d2c4'), Move.from_uci('d2f3'), Move.from_uci('d2b3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('h1e1'), Move.from_uci('d1g1'), Move.from_uci('d1f1'), Move.from_uci('d1e1'), Move.from_uci('c1b1'), Move.from_uci('e3e4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('c2c4')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.063328742980957 seconds ---
# server send message: {"move": "h1e1"}
# server get data: {"fen":"rn3k2/p4p1r/2p3pp/8/8/P3P3/1PPN2PP/2KRR3 w - - 2 21","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d2e4'), Move.from_uci('d2c4'), Move.from_uci('d2f3'), Move.from_uci('d2b3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('e1e2'), Move.from_uci('e1h1'), Move.from_uci('e1g1'), Move.from_uci('e1f1'), Move.from_uci('c1b1'), Move.from_uci('e3e4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('c2c4')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# --- 0.977663516998291 seconds ---
# server send message: {"move": "c2c3"}
# server get data: {"fen":"rn3k2/p6r/2p2ppp/8/8/P1P1P3/1P1N2PP/2KRR3 w - - 0 22","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d2e4'), Move.from_uci('d2c4'), Move.from_uci('d2f3'), Move.from_uci('d2b3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('e1f1')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.1898889541625977 seconds ---
# server send message: {"move": "d2c4"}
# server get data: {"fen":"rn3k2/p2r4/2p2ppp/8/2N5/P1P1P3/1P4PP/2KRR3 w - - 2 23","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4a5'), Move.from_uci('e1e2'), Move.from_uci('e1h1'), Move.from_uci('e1g1'), Move.from_uci('e1f1'), Move.from_uci('d1d7'), Move.from_uci('d1d6'), Move.from_uci('d1d4'), Move.from_uci('d1d2'), Move.from_uci('c1c2'), Move.from_uci('c1b1'), Move.from_uci('e3e4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('b2b4')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 3.3474416732788086 seconds ---
# server send message: {"move": "d1d7"}
# server get data: {"fen":"r4k2/p2n4/2p2ppp/8/2N5/P1P1P3/1P4PP/2K1R3 w - - 0 24","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4a5'), Move.from_uci('e1d1')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.7480909824371338 seconds ---
# server send message: {"move": "c4a5"}
# server get data: {"fen":"r4k2/p7/2p2ppp/N3n3/8/P1P1P3/1P4PP/2K1R3 w - - 2 25","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e1e2'), Move.from_uci('e1h1'), Move.from_uci('e1g1'), Move.from_uci('e1f1'), Move.from_uci('e1d1'), Move.from_uci('c1d2'), Move.from_uci('c1c2'), Move.from_uci('c1d1'), Move.from_uci('c1b1')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.287203311920166 seconds ---
# server send message: {"move": "e1g1"}
# server get data: {"fen":"r4k2/p7/2p3pp/N3np2/8/P1P1P3/1P4PP/2K3R1 w - - 0 26","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a5b7'), Move.from_uci('a5b3'), Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('c1d2'), Move.from_uci('c1c2'), Move.from_uci('c1d1'), Move.from_uci('c1b1'), Move.from_uci('e3e4'), Move.from_uci('c3c4'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('b2b4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.6431457996368408 seconds ---
# server send message: {"move": "e3e4"}
# server get data: {"fen":"r4k2/p7/2p3pp/N4p2/4P3/P1Pn4/1P4PP/2K3R1 w - - 1 27","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c1d2'), Move.from_uci('c1c2'), Move.from_uci('c1b1')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.3386344909667969 seconds ---
# server send message: {"move": "c1b1"}
# server get data: {"fen":"1r3k2/p7/2p3pp/N4p2/4P3/P1Pn4/1P4PP/1K4R1 w - - 3 28","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a5c6'), Move.from_uci('a5c4'), Move.from_uci('b1c2'), Move.from_uci('b1a1'), Move.from_uci('e4f5'), Move.from_uci('b2b3'), Move.from_uci('b2b4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 2.1888198852539062 seconds ---
# server send message: {"move": "a5c4"}
# server get data: {"fen":"1r3k2/p7/2p3pp/8/2N1p3/P1Pn4/1P4PP/1K4R1 w - - 0 29","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('b1c2'), Move.from_uci('b1a2'), Move.from_uci('b1a1'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.815568208694458 seconds ---
# server send message: {"move": "g2g4"}
# server get data: {"fen":"1r4k1/p7/2p3pp/8/2N1p1P1/P1Pn4/1P5P/1K4R1 w - - 1 30","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1g3'), Move.from_uci('g1g2'), Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('b1c2'), Move.from_uci('b1a2'), Move.from_uci('b1a1'), Move.from_uci('g4g5'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('h2h4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 2.247267961502075 seconds ---
# server send message: {"move": "b1a1"}
# server get data: {"fen":"1r5k/p7/2p3pp/8/2N1p1P1/P1Pn4/1P5P/K5R1 w - - 3 31","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4d6'), Move.from_uci('c4a5'), Move.from_uci('c4e3'), Move.from_uci('c4d2'), Move.from_uci('g1g3'), Move.from_uci('g1g2'), Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('g1b1'), Move.from_uci('a1a2'), Move.from_uci('a1b1'), Move.from_uci('g4g5'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('h2h4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 2.251875638961792 seconds ---
# server send message: {"move": "b2b4"}
# server get data: {"fen":"1r6/p6k/2p3pp/8/1PN1p1P1/P1Pn4/7P/K5R1 w - - 1 32","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4d6'), Move.from_uci('c4a5'), Move.from_uci('c4e3'), Move.from_uci('c4d2'), Move.from_uci('c4b2'), Move.from_uci('g1g3'), Move.from_uci('g1g2'), Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('g1b1'), Move.from_uci('a1a2'), Move.from_uci('a1b1'), Move.from_uci('g4g5'), Move.from_uci('b4b5'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('h2h4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 2.3371920585632324 seconds ---
# server send message: {"move": "b4b5"}
# server get data: {"fen":"1r6/p6k/6pp/1Pp5/2N1p1P1/P1Pn4/7P/K5R1 w - - 0 33","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4d6'), Move.from_uci('c4a5'), Move.from_uci('c4e3'), Move.from_uci('c4d2'), Move.from_uci('c4b2'), Move.from_uci('g1g3'), Move.from_uci('g1g2'), Move.from_uci('g1h1'), Move.from_uci('g1f1'), Move.from_uci('g1d1'), Move.from_uci('g1b1'), Move.from_uci('a1a2'), Move.from_uci('a1b1'), Move.from_uci('b5b6'), Move.from_uci('g4g5'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('h2h4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# --- 2.1799020767211914 seconds ---
# server send message: {"move": "c4d6"}
# server get data: {"fen":"1r6/p6k/3N2pp/1P6/2p1p1P1/P1Pn4/7P/K5R1 w - - 0 34","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d6e4'), Move.from_uci('d6c4'), Move.from_uci('g1g3'), Move.from_uci('g1f1'), Move.from_uci('g1b1'), Move.from_uci('a1a2'), Move.from_uci('a1b1'), Move.from_uci('b5b6'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('h2h4')], 0]
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# --- 2.056042194366455 seconds ---
# server send message: {"move": "d6c4"}
# server get data: {"fen":"r7/p6k/6pp/1P6/2N1p1P1/P1Pn4/7P/K5R1 w - - 1 35","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1f1')], 10]
# 1/1 [==============================] - 0s 15ms/step
# --- 1.2455689907073975 seconds ---
# server send message: {"move": "g1f1"}
# server get data: {"fen":"r7/p5k1/6pp/1P6/2N1p1P1/P1Pn4/7P/K4R2 w - - 3 36","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c4d6'), Move.from_uci('c4d2')], 10]
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# --- 1.9061591625213623 seconds ---
# server send message: {"move": "c4d6"}
# server get data: {"fen":"r7/p5k1/3N2pp/1P2n3/4p1P1/P1P5/7P/K4R2 w - - 5 37","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d6e4'), Move.from_uci('g4g5')], 10]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# --- 1.7850673198699951 seconds ---
# server send message: {"move": "d6e4"}
# server get data: {"fen":"r7/p5k1/6pp/1P6/4N1n1/P1P5/7P/K4R2 w - - 0 38","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('h2h3')], 10]
# 1/1 [==============================] - 0s 15ms/step
# --- 2.276843786239624 seconds ---
# server send message: {"move": "h2h3"}
# server get data: {"fen":"r7/p5k1/6pp/1P6/4N3/P1P1n2P/8/K4R2 w - - 1 39","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f1f4'), Move.from_uci('f1f3'), Move.from_uci('f1f2'), Move.from_uci('f1h1'), Move.from_uci('f1g1'), Move.from_uci('f1c1'), Move.from_uci('f1b1')], 0]
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 2.1639959812164307 seconds ---
# server send message: {"move": "f1f3"}
# server get data: {"fen":"r7/p5k1/6pp/1P6/4N3/P1P2R1P/2n5/K7 w - - 3 40","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a1b2')], 10]
# 1/1 [==============================] - 0s 14ms/step
# --- 0.38608407974243164 seconds ---
# server send message: {"move": "a1b2"}
# server get data: {"fen":"4r3/p5k1/6pp/1P6/4N3/P1P2R1P/1Kn5/8 w - - 5 41","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e4f6'), Move.from_uci('e4d6'), Move.from_uci('e4c5'), Move.from_uci('e4g3'), Move.from_uci('e4d2'), Move.from_uci('b2c2')], 10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 3.9418864250183105 seconds ---
# server send message: {"move": "b2c2"}
# server get data: {"fen":"8/p5k1/6pp/1P6/4r3/P1P2R1P/2K5/8 w - - 0 42","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3d3')], 10]
# 1/1 [==============================] - 0s 14ms/step
# --- 1.225158929824829 seconds ---
# server send message: {"move": "f3d3"}
# server get data: {"fen":"6k1/p7/6pp/1P6/4r3/P1PR3P/2K5/8 w - - 2 43","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d3d8'), Move.from_uci('d3d7'), Move.from_uci('d3d6'), Move.from_uci('d3d5'), Move.from_uci('d3d4'), Move.from_uci('d3g3'), Move.from_uci('d3d2'), Move.from_uci('d3d1'), Move.from_uci('c2b3'), Move.from_uci('c2d2'), Move.from_uci('c2b2'), Move.from_uci('c2d1'), Move.from_uci('c2c1'), Move.from_uci('c2b1')], 10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.8353517055511475 seconds ---
# server send message: {"move": "d3d8"}
# server get data: {"fen":"3R4/p6k/6pp/1P6/4r3/P1P4P/2K5/8 w - - 4 44","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d8d7')], 20]
# 1/1 [==============================] - 0s 13ms/step
# --- 0.7463665008544922 seconds ---
# server send message: {"move": "d8d7"}
# server get data: {"fen":"7k/p2R4/6pp/1P6/4r3/P1P4P/2K5/8 w - - 6 45","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d7a7')], 20]
# 1/1 [==============================] - 0s 13ms/step
# --- 0.37460899353027344 seconds ---
# server send message: {"move": "d7a7"}
# server get data: {"fen":"6k1/R7/6pp/1P6/4r3/P1P4P/2K5/8 w - - 1 46","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a7a8'), Move.from_uci('a7d7'), Move.from_uci('a7c7'), Move.from_uci('a7b7'), Move.from_uci('a7a6'), Move.from_uci('a7a5'), Move.from_uci('c2d3'), Move.from_uci('c2b3'), Move.from_uci('c2d2'), Move.from_uci('c2b2'), Move.from_uci('c2d1'), Move.from_uci('c2c1'), Move.from_uci('c2b1'), Move.from_uci('b5b6'), Move.from_uci('a3a4')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.7554686069488525 seconds ---
# server send message: {"move": "b5b6"}
# server get data: {"fen":"7k/R7/1P4pp/8/4r3/P1P4P/2K5/8 w - - 1 47","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a7a8'), Move.from_uci('a7f7'), Move.from_uci('a7d7'), Move.from_uci('a7c7'), Move.from_uci('a7b7'), Move.from_uci('a7a6'), Move.from_uci('a7a5'), Move.from_uci('c2d3'), Move.from_uci('c2b3'), Move.from_uci('c2d2'), Move.from_uci('c2b2'), Move.from_uci('c2d1'), Move.from_uci('c2c1'), Move.from_uci('c2b1'), Move.from_uci('b6b7'), Move.from_uci('a3a4')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.7533860206604004 seconds ---
# server send message: {"move": "b6b7"}
# server get data: {"fen":"7k/RP6/6pp/8/8/P1P4P/2K1r3/8 w - - 1 48","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('c2d3'), Move.from_uci('c2b3'), Move.from_uci('c2d1'), Move.from_uci('c2c1'), Move.from_uci('c2b1')], 20]
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.2206892967224121 seconds ---
# server send message: {"move": "c2d3"}
# server get data: {"fen":"4r2k/RP6/6pp/8/8/P1PK3P/8/8 w - - 3 49","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('a7a8'), Move.from_uci('a7a6')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.4292011260986328 seconds ---
# server send message: {"move": "a7a6"}
# server get data: {"fen":"3r3k/1P6/R5pp/8/8/P1PK3P/8/8 w - - 5 50","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('d3e4'), Move.from_uci('d3c4'), Move.from_uci('d3e3'), Move.from_uci('d3e2'), Move.from_uci('d3c2')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.2997865676879883 seconds ---
# server send message: {"move": "d3e2"}
# server get data: {"fen":"4r2k/1P6/R5pp/8/8/P1P4P/4K3/8 w - - 7 51","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e2f3'), Move.from_uci('e2d3'), Move.from_uci('e2f2'), Move.from_uci('e2d2'), Move.from_uci('e2f1'), Move.from_uci('e2d1')], 20]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.3638277053833008 seconds ---
# server send message: {"move": "e2f3"}
# server get data: {"fen":"5r1k/1P6/R5pp/8/8/P1P2K1P/8/8 w - - 9 52","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3g4'), Move.from_uci('f3e4'), Move.from_uci('f3g3'), Move.from_uci('f3e3'), Move.from_uci('f3g2'), Move.from_uci('f3e2')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.35118937492370605 seconds ---
# server send message: {"move": "f3e2"}
# server get data: {"fen":"4r2k/1P6/R5pp/8/8/P1P4P/4K3/8 w - - 11 53","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e2f3'), Move.from_uci('e2d3'), Move.from_uci('e2f2'), Move.from_uci('e2d2'), Move.from_uci('e2f1'), Move.from_uci('e2d1')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.3479435443878174 seconds ---
# server send message: {"move": "e2f3"}
# server get data: {"fen":"5r1k/1P6/R5pp/8/8/P1P2K1P/8/8 w - - 13 54","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3g4'), Move.from_uci('f3e4'), Move.from_uci('f3g3'), Move.from_uci('f3e3'), Move.from_uci('f3g2'), Move.from_uci('f3e2')], 20]
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.3459451198577881 seconds ---
# server send message: {"move": "f3e2"}
# server get data: {"fen":"4r2k/1P6/R5pp/8/8/P1P4P/4K3/8 w - - 15 55","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e2f3'), Move.from_uci('e2d3'), Move.from_uci('e2f2'), Move.from_uci('e2d2'), Move.from_uci('e2f1'), Move.from_uci('e2d1')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.35727357864379883 seconds ---
# server send message: {"move": "e2f3"}
# server get data: {"fen":"5r1k/1P6/R5pp/8/8/P1P2K1P/8/8 w - - 17 56","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3g4'), Move.from_uci('f3e4'), Move.from_uci('f3g3'), Move.from_uci('f3e3'), Move.from_uci('f3g2'), Move.from_uci('f3e2')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.350294828414917 seconds ---
# server send message: {"move": "f3e2"}
# server get data: {"fen":"4r2k/1P6/R5pp/8/8/P1P4P/4K3/8 w - - 19 57","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('e2f3'), Move.from_uci('e2d3'), Move.from_uci('e2f2'), Move.from_uci('e2d2'), Move.from_uci('e2f1'), Move.from_uci('e2d1')], 20]
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 0.34814977645874023 seconds ---
# server send message: {"move": "e2f3"}
# server get data: {"fen":"5r1k/1P6/R5pp/8/8/P1P2K1P/8/8 w - - 21 58","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('f3g4'), Move.from_uci('f3e4'), Move.from_uci('f3g3'), Move.from_uci('f3e3'), Move.from_uci('f3g2'), Move.from_uci('f3e2')], 20]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 0.3558769226074219 seconds ---
# server send message: {"move": "f3e2"}
# server get data: {"fen":"rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('b1a3'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('a2a3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4'), Move.from_uci('a2a4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 1.2221951484680176 seconds ---
# server send message: {"move": "a2a3"}
# server get data: {"fen":"rnbqkbnr/pppppp1p/6p1/8/8/P7/1PPPPPPP/RNBQKBNR w KQkq - 0 2","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 1.3900885581970215 seconds ---
# server send message: {"move": "e2e3"}
# server get data: {"fen":"rnbqkb1r/pppppp1p/5np1/8/8/P3P3/1PPP1PPP/RNBQKBNR w KQkq - 1 3","algorithm":"DEEPLODOCUS"}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('g1e2'), Move.from_uci('f1b5'), Move.from_uci('f1c4'), Move.from_uci('f1d3'), Move.from_uci('f1e2'), Move.from_uci('e1e2'), Move.from_uci('d1f3'), Move.from_uci('d1e2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 2.4687702655792236 seconds ---
# server send message: {"move": "f1c4"}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_131737/1827424082.py in <module>
# ----> 1 Server().run()
#
# /tmp/ipykernel_131737/3687756465.py in run(self)
#      14             print("server starts")
#      15             while True:
# ---> 16                 con, addr = self.server.accept()
#      17                 json_str = con.recv(1024).decode('utf-8').replace('\n', '')
#      18
#
# /usr/lib/python3.10/socket.py in accept(self)
#     291         For IP sockets, the address info is a pair (hostaddr, port).
#     292         """
# --> 293         fd, addr = self._accept()
#     294         sock = socket(self.family, self.type, self.proto, fileno=fd)
#     295         # Issue #7995: if no default timeout is set and the listening
#
# KeyboardInterrupt:

# %% [markdown]
# ## Lichess bot

# %%
import berserk
import threading
import chess
import random
import traceback

class Game(threading.Thread):
    def __init__(self, client, game_id, color, **kwargs):
        super().__init__(**kwargs)
        self.game_id = game_id
        self.client = client
        self.color = color
        self.stream = client.bots.stream_game_state(game_id)
        self.current_state = next(self.stream)

    def run(self):
        for event in self.stream:
            if event['type'] == 'gameState':
                self.handle_state_change(event)

    def handle_state_change(self, state):
        if self.color.upper() == 'BLACK' and len(state['moves'].split()) % 2 == 0:
            board = chess.Board()
            for move in state['moves'].split():
                board.push(chess.Move.from_uci(move))

            if not board.is_game_over():
                try:
                    client.bots.make_move(self.game_id, get_best_move_by_deeplodocus(board.fen()))
                except Exception as e:
                    print(e)
        elif self.color.upper() == 'WHITE' and len(state['moves'].split()) % 2 == 1:
            board = chess.Board()
            for move in state['moves'].split():
                board.push(chess.Move.from_uci(move))
                
            if not board.is_game_over():
                try:
                    client.bots.make_move(self.game_id, get_best_move_by_deeplodocus(board.fen()))
                except Exception as e:
                    print(e)

with open("lichess_api_key.txt") as file:
    token = file.readline().replace('\n', '')

session = berserk.TokenSession(token)
client = berserk.Client(session=session)

# client.account.upgrade_to_bot()


for event in client.bots.stream_incoming_events():
    if event['type'] == 'challenge':
        if event['challenge']['variant']['key'] == 'standard':
                    # and event['challenge']['timeControl']['show'] == '1+1':
            try:
                client.bots.accept_challenge(event['challenge']['id'])
                print("Accept")
            except Exception as e:
                print(e)
    elif event['type'] == 'gameStart':
        if event['game']['color'] == 'white':
            c = 'black'
            board = chess.Board(fen=event['game']['fen'])
            
            client.bots.make_move(event['game']['gameId'], get_best_move_by_deeplodocus(board.fen()))
            game = Game(client, event['game']['gameId'], c)
            game.start()
        else:
            c = 'white'
            game = Game(client, event['game']['gameId'], c)
            game.start()
# Out:
# HTTP 404: Not Found: {'error': 'Not found'}
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('b1a3'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('a2a3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4'), Move.from_uci('a2a4')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# --- 1.3325645923614502 seconds ---
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('g2g3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('g2g4'), Move.from_uci('f2f4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 2.302968740463257 seconds ---
# [[Move.from_uci('g1h3'), Move.from_uci('g1f3'), Move.from_uci('f1h3'), Move.from_uci('f1g2'), Move.from_uci('b1c3'), Move.from_uci('a1a2'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('d2d3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('e2e4'), Move.from_uci('d2d4'), Move.from_uci('c2c4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 3.96213960647583 seconds ---
# [[Move.from_uci('c1g5')], 0]
# 1/1 [==============================] - 0s 14ms/step
# --- 4.972689867019653 seconds ---
# [[Move.from_uci('g5f6'), Move.from_uci('g5h4'), Move.from_uci('g1f3'), Move.from_uci('f1g2'), Move.from_uci('e1d2'), Move.from_uci('d1d2'), Move.from_uci('d1c1'), Move.from_uci('b1c3'), Move.from_uci('b1d2'), Move.from_uci('a1a2'), Move.from_uci('h2h3'), Move.from_uci('f2f3'), Move.from_uci('c2c3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('b2b4')], 0]
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.5236711502075195 seconds ---
# [[Move.from_uci('f1h3'), Move.from_uci('c2c3')], 0]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 3.8591060638427734 seconds ---
# [[Move.from_uci('g1h3')], 0]
# 1/1 [==============================] - 0s 14ms/step
# --- 2.507269859313965 seconds ---
# [[Move.from_uci('h3g1'), Move.from_uci('h1f1'), Move.from_uci('e1d2'), Move.from_uci('e1f1'), Move.from_uci('d1d2'), Move.from_uci('d1c1'), Move.from_uci('b1d2'), Move.from_uci('a1a2'), Move.from_uci('f2f3'), Move.from_uci('e2e3'), Move.from_uci('c2c3')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 3.3242766857147217 seconds ---
# [[Move.from_uci('d2f3'), Move.from_uci('d2b3'), Move.from_uci('e2e3'), Move.from_uci('c2c3')], 0]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 4.872641086578369 seconds ---
# [[Move.from_uci('c3c4')], 0]
# 1/1 [==============================] - 0s 14ms/step
# --- 5.642076253890991 seconds ---
# [[Move.from_uci('h3g1')], -10]
# 1/1 [==============================] - 0s 14ms/step
# --- 5.432515621185303 seconds ---
# [[Move.from_uci('d2e4'), Move.from_uci('f2f4')], 0]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 6.437271595001221 seconds ---
# [[Move.from_uci('f4e5'), Move.from_uci('c4b5')], 0]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 17.939989805221558 seconds ---
# [[Move.from_uci('d2e4'), Move.from_uci('d2f3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('g1f3'), Move.from_uci('e1f2'), Move.from_uci('e1f1'), Move.from_uci('d1b3'), Move.from_uci('d1c2'), Move.from_uci('d1c1'), Move.from_uci('d1b1'), Move.from_uci('a1c1'), Move.from_uci('a1b1'), Move.from_uci('f4e5'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('b2b3'), Move.from_uci('h2h4'), Move.from_uci('b2b4')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 12.92221999168396 seconds ---
# [[Move.from_uci('d2f3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('g1f3'), Move.from_uci('e1f2'), Move.from_uci('e1f1'), Move.from_uci('d1b3'), Move.from_uci('d1c2'), Move.from_uci('d1c1'), Move.from_uci('d1b1'), Move.from_uci('a1c1'), Move.from_uci('a1b1'), Move.from_uci('b2b3')], -10]
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 5.7490785121917725 seconds ---
# [[Move.from_uci('f3g1'), Move.from_uci('d2e4'), Move.from_uci('d2b1'), Move.from_uci('d1b3'), Move.from_uci('d1c2'), Move.from_uci('d1c1'), Move.from_uci('d1b1'), Move.from_uci('a1c1'), Move.from_uci('a1b1'), Move.from_uci('a3a4'), Move.from_uci('h2h3'), Move.from_uci('b2b3'), Move.from_uci('h2h4')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 10.054847955703735 seconds ---
# [[Move.from_uci('f3e5'), Move.from_uci('f3g1'), Move.from_uci('d2e4'), Move.from_uci('h1g1'), Move.from_uci('d1b3')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 7.836480140686035 seconds ---
# [[Move.from_uci('d2f3'), Move.from_uci('d2f1'), Move.from_uci('d2b1'), Move.from_uci('h1g1'), Move.from_uci('h1f1'), Move.from_uci('e1f2'), Move.from_uci('e1f1'), Move.from_uci('d1b3'), Move.from_uci('d1c2'), Move.from_uci('c1c5'), Move.from_uci('c1c2'), Move.from_uci('c1b1'), Move.from_uci('c1a1'), Move.from_uci('e1g1')], -10]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 6.674926519393921 seconds ---
# [[Move.from_uci('f1f3'), Move.from_uci('f1f2'), Move.from_uci('f1e1')], -10]
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 13.089271068572998 seconds ---
# [[Move.from_uci('d2f3'), Move.from_uci('h2g3')], -40]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# --- 14.292011499404907 seconds ---
# [[Move.from_uci('g1f1')], -30]
# 1/1 [==============================] - 0s 14ms/step
# --- 0.6553554534912109 seconds ---
# [[Move.from_uci('f1f2'), Move.from_uci('f1g1')], -40]
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 0.4557461738586426 seconds ---
# [[Move.from_uci('g1f1')], -30]
# 1/1 [==============================] - 0s 15ms/step
# --- 0.6725296974182129 seconds ---
# [[Move.from_uci('f1f2'), Move.from_uci('f1g1')], -40]
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# --- 0.45023465156555176 seconds ---
# [[Move.from_uci('g1f1')], -30]
# 1/1 [==============================] - 0s 13ms/step
# --- 0.6794633865356445 seconds ---
# HTTP 400: Bad Request: {'error': 'Not your turn, or game already over'}
# [[Move.from_uci('g1f1')], -30]
# 1/1 [==============================] - 0s 13ms/step
# --- 0.6402769088745117 seconds ---
# HTTP 400: Bad Request: {'error': 'Not your turn, or game already over'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_131737/4287586275.py in <module>
#      50
#      51
# ---> 52 for event in client.bots.stream_incoming_events():
#      53     if event['type'] == 'challenge':
#      54         if event['challenge']['variant']['key'] == 'standard':
#
# ~/.local/lib/python3.10/site-packages/berserk/clients/bots.py in stream_incoming_events(self)
#      18         """
#      19         path = "/api/stream/event"
# ---> 20         yield from self._r.get(path, stream=True)
#      21
#      22     def stream_game_state(self, game_id: str) -> Iterator[Dict[str, Any]]:
#
# ~/.local/lib/python3.10/site-packages/berserk/formats.py in parse_stream(self, response)
#      94         :return: iterator over multiple JSON objects
#      95         """
# ---> 96         for line in response.iter_lines():
#      97             if line:
#      98                 decoded_line = line.decode("utf-8")
#
# ~/.local/lib/python3.10/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     863         pending = None
#     864
# --> 865         for chunk in self.iter_content(
#     866             chunk_size=chunk_size, decode_unicode=decode_unicode
#     867         ):
#
# ~/.local/lib/python3.10/site-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# /usr/lib/python3/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# /usr/lib/python3/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# /usr/lib/python3/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1272                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273                   self.__class__)
# -> 1274             return self.read(nbytes, buffer)
#    1275         else:
#    1276             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1128         try:
#    1129             if buffer is not None:
# -> 1130                 return self._sslobj.read(len, buffer)
#    1131             else:
#    1132                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
